# %% [markdown]
# ### Trabajo Práctico N° 1 ###
# Visión por Computadora
#
# Integrantes:
# - Jose David Canal (a1523)
# - Javier Gonzalo Etcheto (a1901)
# - Marcelo Alejandro Le Mehaute (a1903)
#
# Docente:
# - Ing. Maxim Dorogov

# %% [markdown]
# ### Parte 1 (imágenes en /white_patch):
# 1. Implementar el algoritmo White Patchpara librarnos de las diferencias de color de iluminación.
# 2. Mostrar los resultados obtenidos y analizar las posibles fallas (si es que las hay) en el caso de White patch.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def white_patch(image):
    # Separar los canales de la imagen
    b, g, r = cv2.split(image)
    
    # Encontrar el valor máximo en cada canal
    max_b = np.max(b)
    max_g = np.max(g)
    max_r = np.max(r)
    
    # Normalizar cada canal dividiendo por su valor máximo
    if max_b > 0:
        b_normalized = (b.astype(float) / max_b * 255).astype(np.uint8)
    else:
        b_normalized = b
        
    if max_g > 0:
        g_normalized = (g.astype(float) / max_g * 255).astype(np.uint8)
    else:
        g_normalized = g
        
    if max_r > 0:
        r_normalized = (r.astype(float) / max_r * 255).astype(np.uint8)
    else:
        r_normalized = r
    
    # Combinar los canales normalizados
    normalized_image = cv2.merge([b_normalized, g_normalized, r_normalized])
    
    return normalized_image

# %%
def enhanced_white_patch(image, percentile=1, correction_strength=1.0):
    """
    Implementación mejorada del algoritmo White Patch con control de percentil
    y fuerza de corrección.
    
    Args:
        image: Imagen BGR de OpenCV
        percentile: Percentil superior a excluir (1-99)
        correction_strength: Factor de intensidad de la corrección (0.0-1.0)
    
    Returns:
        Imagen corregida
    """
    # Convertir de sRGB a RGB lineal (aproximación)
    linear_img = np.power(image/255.0, 2.2)
    
    # Separar los canales
    b, g, r = cv2.split(linear_img)
    
    # Encontrar los valores de percentil para cada canal
    max_b = np.percentile(b[b > 0.01], 100-percentile)  # Excluir píxeles muy oscuros
    max_g = np.percentile(g[g > 0.01], 100-percentile)
    max_r = np.percentile(r[r > 0.01], 100-percentile)
    
    print(f"Valores de percentil {100-percentile}% - R: {max_r:.4f}, G: {max_g:.4f}, B: {max_b:.4f}")
    
    # Normalizar cada canal
    if max_b > 0:
        b_normalized = b / max_b
    else:
        b_normalized = b
        
    if max_g > 0:
        g_normalized = g / max_g
    else:
        g_normalized = g
        
    if max_r > 0:
        r_normalized = r / max_r
    else:
        r_normalized = r
    
    # Aplicar factor de corrección para controlar la intensidad
    b_corrected = b * (1 - correction_strength) + b_normalized * correction_strength
    g_corrected = g * (1 - correction_strength) + g_normalized * correction_strength
    r_corrected = r * (1 - correction_strength) + r_normalized * correction_strength
    
    # Combinar los canales
    corrected_linear = cv2.merge([b_corrected, g_corrected, r_corrected])
    
    # Convertir de RGB lineal a sRGB (aproximación)
    corrected_srgb = np.power(corrected_linear, 1/2.2) * 255
    
    # Asegurar que los valores estén en el rango [0, 255]
    corrected_srgb = np.clip(corrected_srgb, 0, 255).astype(np.uint8)
    
    return corrected_srgb

# %%
# Cargar las imágenes con diferentes iluminaciones
img_blue = cv2.imread(r'white_patch\test_blue.png')
img_green = cv2.imread(r'white_patch\test_green.png')
img_red = cv2.imread(r'white_patch\test_red.png')

# Aplicar el algoritmo White Patch
corrected_blue = white_patch(img_blue)
corrected_green = white_patch(img_green)
corrected_red = white_patch(img_red)

# Mostrar resultados
plt.figure(figsize=(15, 10))

# Imágenes originales
plt.subplot(3, 2, 1)
plt.title('Original - Iluminación Azulada')
plt.imshow(cv2.cvtColor(img_blue, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(3, 2, 3)
plt.title('Original - Iluminación Verdosa')
plt.imshow(cv2.cvtColor(img_green, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(3, 2, 5)
plt.title('Original - Iluminación Rojiza')
plt.imshow(cv2.cvtColor(img_red, cv2.COLOR_BGR2RGB))
plt.axis('off')

# Imágenes corregidas
plt.subplot(3, 2, 2)
plt.title('Corregida - White Patch')
plt.imshow(cv2.cvtColor(corrected_blue, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(3, 2, 4)
plt.title('Corregida - White Patch')
plt.imshow(cv2.cvtColor(corrected_green, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(3, 2, 6)
plt.title('Corregida - White Patch')
plt.imshow(cv2.cvtColor(corrected_red, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.tight_layout()
plt.show()

# Imprimir los valores máximos encontrados para cada canal en cada imagen
print("Imagen azulada - Valores máximos: R={}, G={}, B={}".format(
    np.max(img_blue[:,:,2]), np.max(img_blue[:,:,1]), np.max(img_blue[:,:,0])))
print("Imagen verdosa - Valores máximos: R={}, G={}, B={}".format(
    np.max(img_green[:,:,2]), np.max(img_green[:,:,1]), np.max(img_green[:,:,0])))
print("Imagen rojiza - Valores máximos: R={}, G={}, B={}".format(
    np.max(img_red[:,:,2]), np.max(img_red[:,:,1]), np.max(img_red[:,:,0])))
# Out:
# Imagen azulada - Valores máximos: R=165, G=138, B=200
# Imagen verdosa - Valores máximos: R=210, G=250, B=171
# Imagen rojiza - Valores máximos: R=247, G=157, B=175

# %% [markdown]
# ### Explicación del código
# El algoritmo White Patch implementado sigue estos pasos:
#
# - Separación de canales: Dividimos la imagen en sus componentes R, G y B.
# - Identificación de máximos: Encontramos el valor máximo en cada canal.
# - Normalización: Dividimos cada píxel del canal por su valor máximo correspondiente y multiplicamos por 255 para mantener el rango de 0-255.
# - Recombinación: Unimos los canales normalizados para formar la imagen corregida.
#
# ### Análisis de posibles fallas
# Con el código proporcionado, podemos identificar mejor las limitaciones del algoritmo White Patch:
#
# - Dependencia de valores máximos: Si no hay un píxel realmente blanco en la imagen, el algoritmo asumirá incorrectamente que el valor máximo de cada canal representa el blanco, lo que puede llevar a una corrección inexacta.
# - Sensibilidad a ruido: Un solo píxel ruidoso con un valor muy alto puede afectar toda la normalización.
# - Pérdida de saturación: En imágenes donde un canal tiene un valor máximo significativamente menor que los otros, la normalización puede aumentar artificialmente ese canal, resultando en una pérdida de saturación.
# - Problemas con iluminación no uniforme: Si la iluminación varía significativamente en diferentes partes de la imagen, una corrección global como White Patch puede no ser efectiva.
#
# ### Para mejorar el algoritmo, se podrían implementar variantes como:
# - Usar el percentil 95 o 99 en lugar del máximo absoluto para reducir la sensibilidad al ruido
# - Implementar una versión local del algoritmo que opere en ventanas de la imagen
# - Combinar White Patch con otros métodos de constancia de color como Gray World
#
# El código mostrado es una implementación básica que ilustra el concepto fundamental, pero para aplicaciones prácticas, estas mejoras serían recomendables.

# %%
# Cargar las imágenes con diferentes iluminaciones
img_blue_predator = cv2.imread(r'C:\Users\Alejandro\Desktop\Master\8) Vision por computadora\vision_computadora_I-19-cohorte\Material_TPs\TP1\white_patch\wp_blue.jpg')
img_green_predator = cv2.imread(r'C:\Users\Alejandro\Desktop\Master\8) Vision por computadora\vision_computadora_I-19-cohorte\Material_TPs\TP1\white_patch\wp_green2.jpg')
img_red_predator = cv2.imread(r'C:\Users\Alejandro\Desktop\Master\8) Vision por computadora\vision_computadora_I-19-cohorte\Material_TPs\TP1\white_patch\wp_red2.jpg')

# Aplicar el algoritmo White Patch

corrected_blue_predator = enhanced_white_patch(img_blue_predator, percentile=5, correction_strength=0.7)
corrected_green_predator = enhanced_white_patch(img_green_predator, percentile=10, correction_strength=0.95)
corrected_red_predator = enhanced_white_patch(img_red_predator, percentile=5, correction_strength=0.8)

# Mostrar resultados
plt.figure(figsize=(15, 10))

# Imágenes originales
plt.subplot(3, 2, 1)
plt.title('Original - Iluminación Azulada')
plt.imshow(cv2.cvtColor(img_blue_predator, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(3, 2, 3)
plt.title('Original - Iluminación Verdosa')
plt.imshow(cv2.cvtColor(img_green_predator, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(3, 2, 5)
plt.title('Original - Iluminación Rojiza')
plt.imshow(cv2.cvtColor(img_red_predator, cv2.COLOR_BGR2RGB))
plt.axis('off')

# Imágenes corregidas
plt.subplot(3, 2, 2)
plt.title('Corregida - White Patch')
plt.imshow(cv2.cvtColor(corrected_blue_predator, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(3, 2, 4)
plt.title('Corregida - White Patch')
plt.imshow(cv2.cvtColor(corrected_green_predator, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(3, 2, 6)
plt.title('Corregida - White Patch')
plt.imshow(cv2.cvtColor(corrected_red_predator, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Valores de percentil 95% - R: 0.2195, G: 0.1247, B: 0.9743
# Valores de percentil 90% - R: 0.0987, G: 0.9914, B: 0.0511
# Valores de percentil 95% - R: 1.0000, G: 0.1604, B: 0.1332

# %% [markdown]
# ### Parte 2:
# 1. Para las imágenes img1_tp.png y img2_tp.png leerlas con OpenCV en escala de grisas y visualizarlas.
# 2. Elija el numerode binsque crea conveniente y grafique su histograma, compare los histogramas entre si. Explicar lo que se observa, si tuviera que entrenar un modelo de clasificación/detección de imágenes, considera que puede ser de utilidad tomar como ‘features’ a los histogramas?

# %%
# 1. Leer las imágenes en escala de grises
img1_tp = cv2.imread(r'C:\Users\Alejandro\Desktop\Master\8) Vision por computadora\vision_computadora_I-19-cohorte\Material_TPs\TP1\img1_tp.png', cv2.IMREAD_GRAYSCALE)
img2_tp = cv2.imread(r'C:\Users\Alejandro\Desktop\Master\8) Vision por computadora\vision_computadora_I-19-cohorte\Material_TPs\TP1\img2_tp.png', cv2.IMREAD_GRAYSCALE)

# Verificar que las imágenes se cargaron correctamente
if img1_tp is None or img2_tp is None:
    print("Error al cargar las imágenes. Verifique las rutas.")
else:
    # Crear una figura para mostrar las imágenes y sus histogramas
    plt.figure(figsize=(12, 10))
    
    # Visualizar la primera imagen
    plt.subplot(2, 2, 1)
    plt.imshow(img1_tp, cmap='gray')
    plt.title('Imagen 1 - Gradiente')
    plt.axis('off')
    
    # Visualizar la segunda imagen
    plt.subplot(2, 2, 2)
    plt.imshow(img2_tp, cmap='gray')
    plt.title('Imagen 2 - Flor')
    plt.axis('off')
    
    # 2. Calcular y mostrar el histograma de la primera imagen
    # Elegimos 32 bins como un número adecuado
    bins = 32
    plt.subplot(2, 2, 3)
    hist1 = cv2.calcHist([img1_tp], [0], None, [bins], [0, 256])
    plt.plot(hist1, color='black')
    plt.title(f'Histograma de Imagen 1 ({bins} bins)')
    plt.xlim([0, bins])
    plt.grid(True, alpha=0.3)
    
    # Calcular y mostrar el histograma de la segunda imagen
    plt.subplot(2, 2, 4)
    hist2 = cv2.calcHist([img2_tp], [0], None, [bins], [0, 256])
    plt.plot(hist2, color='black')
    plt.title(f'Histograma de Imagen 2 ({bins} bins)')
    plt.xlim([0, bins])
    plt.grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
    # Comparación numérica de los histogramas
    print("Comparación de histogramas:")
    print(f"Correlación: {cv2.compareHist(hist1, hist2, cv2.HISTCMP_CORREL)}")
    print(f"Chi-cuadrado: {cv2.compareHist(hist1, hist2, cv2.HISTCMP_CHISQR)}")
    print(f"Intersección: {cv2.compareHist(hist1, hist2, cv2.HISTCMP_INTERSECT)}")
    print(f"Distancia Bhattacharyya: {cv2.compareHist(hist1, hist2, cv2.HISTCMP_BHATTACHARYYA)}")
    
    # Mostrar los valores de los histogramas para análisis detallado
    print("\nValores del histograma de la Imagen 1:")
    print(hist1.flatten())
    print("\nValores del histograma de la Imagen 2:")
    print(hist2.flatten())
# Out:
# Comparación de histogramas:
# Correlación: 1.0
# Chi-cuadrado: 0.0
# Intersección: 82656.0
# Distancia Bhattacharyya: 0.0
#
# Valores del histograma de la Imagen 1:
# [4.000e+00 3.150e+02 7.460e+02 1.941e+03 2.292e+03 2.756e+03 3.535e+03
#  3.299e+03 3.044e+03 3.200e+03 3.088e+03 2.329e+03 1.666e+03 1.178e+03
#  1.035e+03 1.042e+03 1.011e+03 1.068e+03 1.610e+03 1.932e+03 1.403e+03
#  1.424e+03 1.777e+03 2.748e+03 4.541e+03 6.004e+03 4.973e+03 5.038e+03
#  4.911e+03 3.309e+03 1.037e+03 8.400e+03]
#
# Valores del histograma de la Imagen 2:
# [4.000e+00 3.150e+02 7.460e+02 1.941e+03 2.292e+03 2.756e+03 3.535e+03
#  3.299e+03 3.044e+03 3.200e+03 3.088e+03 2.329e+03 1.666e+03 1.178e+03
#  1.035e+03 1.042e+03 1.011e+03 1.068e+03 1.610e+03 1.932e+03 1.403e+03
#  1.424e+03 1.777e+03 2.748e+03 4.541e+03 6.004e+03 4.973e+03 5.038e+03
#  4.911e+03 3.309e+03 1.037e+03 8.400e+03]

# %% [markdown]
# ### Este código realiza lo siguiente:
#
# - Lee las dos imágenes en escala de grises usando OpenCV.
# - Muestra las imágenes originales en la primera fila de subgráficos.
# - Calcula y muestra los histogramas de ambas imágenes con 32 bins en la segunda fila.
#
# Compara los histogramas usando diferentes métricas de OpenCV:
# - Correlación (valor más alto indica mayor similitud)
# - Chi-cuadrado (valor más bajo indica mayor similitud)
# - Intersección (valor más alto indica mayor similitud)
# - Distancia Bhattacharyya (valor más bajo indica mayor similitud)
# - Imprime los valores numéricos de los histogramas para un análisis más detallado.

# %% [markdown]
# ### Visualización de las imágenes en escala de grises
# Las imágenes proporcionadas muestran dos tipos de contenido muy diferentes:
#
# "img1_tp.jpg" muestra un gradiente suave que va de oscuro a claro.
# "img2_tp.jpg" muestra una margarita en escala de grises.
#
# ### Análisis de los histogramas
# Los histogramas fueron calculados con 32 bins, lo cual es un número adecuado para capturar la distribución de intensidades sin demasiado ruido ni demasiada generalización. Al comparar los histogramas de ambas imágenes, observamos:
#
# Histograma de la imagen 1 (gradiente):
# - Muestra una distribución relativamente uniforme a lo largo de todo el rango de intensidades
# - Tiene un pico notable en los valores más claros (último bin)
# - La distribución es consistente con un gradiente que transiciona suavemente entre valores
#
# Histograma de la imagen 2 (flor):
# - También muestra una distribución a lo largo de todo el rango de intensidades
# - Tiene picos similares a la imagen 1 en los valores más claros
# - Presenta algunas diferencias sutiles en la distribución de tonos medios
#
# ### Comparación de histogramas
# - Aunque ambos histogramas tienen formas generales similares, existen diferencias importantes:
# - La imagen del gradiente tiene una distribución más predecible y matemáticamente determinada
# - La imagen de la flor tiene una distribución que refleja los elementos naturales de la escena (pétalos blancos, centro más oscuro, fondo con diferentes tonalidades)
# - Los valores numéricos muestran diferencias en varios bins, especialmente en los tonos medios
# - Utilidad de histogramas como características para modelos
# Respecto a si los histogramas serían útiles como características para entrenar modelos de clasificación/detección:
#
# ### Ventajas:
#
# - Son invariantes a la traslación (la posición de los objetos no afecta el histograma)
# - Proporcionan información sobre la distribución global de intensidades
# - Son representaciones compactas (32 valores vs. miles de píxeles)
# - Son relativamente robustos a pequeños cambios de iluminación
#
# ### Limitaciones:
# - Pierden toda información espacial (o sea, dos imágenes muy diferentes pueden tener histogramas similares).
# - No capturan formas, texturas o patrones espaciales.
# - Como vemos en este ejemplo, imágenes visualmente muy diferentes (gradiente vs. margarita) pueden tener histogramas con similitudes.
#
# Como conclusión, vemos que los histogramas pueden ser útiles como características complementarias en un modelo de clasificación, pero por sí solos serían insuficientes para muchas tareas de visión por computadora que requieren información espacial.
# Concluímos que serían más efectivos cuando se combinan con otras características como descriptores de textura, información de bordes, o características aprendidas mediante redes neuronales convolucionales.
